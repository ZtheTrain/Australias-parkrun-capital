# %% [markdown]
# # The questions I will be asking in my data analysis
#
# I've successfully scraped the latest results page for Albert Melbourne so now I will be looking at what questions I want my data analysis to answer and how I find the answers to those questions for Albert Melbourne first and then for Albert **and** the other 48 Melbourne parkruns.
#
# **I have limited myself to three questions to ask in my data analysis:**
#
# * Which is the most popular parkrun in Melbourne this week? Most number of participants.
# * Which is the speediest course? As defined by the mean of everyone's times.
# * Which is the speediest course? When looking at it in terms of the mean of age grading instead, so doesn't discriminate against courses that skew older in terms of participants.

# %%
# Date of event and number of participants

import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' 
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/114.0.0.0 Safari/537.36'
}

response = requests.get('https://www.parkrun.com.au/albertmelbourne/results/latestresults/', headers=headers)
response.raise_for_status()

# Parse the HTML content using BeautifulSoup
doc = BeautifulSoup(response.content, 'html.parser')

# Extract the event date
date_element = doc.find('span', class_='format-date')
event_date = date_element.text.strip() if date_element else 'Date not found'

# Extract the total number of participants (position of the last finisher)
table_rows = doc.select('table tbody tr')
total_participants = len(table_rows)

# Output the results
print(f"Event Date: {event_date}")
print(f"Total Participants: {total_participants}")
# Out:
# Event Date: 28/06/2025
# Total Participants: 762

# %%
# Updated scraper script to also get mean time. 

from datetime import timedelta
import re

# Extract event date
date_element = doc.find('span', class_='format-date')
event_date = date_element.text.strip() if date_element else 'Date not found'

# Extract the total number of participants (position of the last finisher)
table_rows = doc.select('table tbody tr')
total_participants = len(table_rows)

# Extract time values
rows = doc.select('table tbody tr')
times = []

for row in rows:
    cols = row.find_all('td')
    if len(cols) < 6:
        continue

    time_raw = cols[5].text.strip()

    # Use regex to extract time string (HH:MM:SS or MM:SS)
    time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
    if time_match:
        time_str = time_match.group(1)
        time_parts = time_str.split(':')

        if len(time_parts) == 2:  # MM:SS
            minutes, seconds = map(int, time_parts)
            td = timedelta(minutes=minutes, seconds=seconds)
        elif len(time_parts) == 3:  # HH:MM:SS
            hours, minutes, seconds = map(int, time_parts)
            td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
        else:
            continue  # unexpected format, skip

        times.append(td)

# Calculate average time
if times:
    average_time = sum(times, timedelta()) / len(times)
    avg_minutes = int(average_time.total_seconds() // 60)
    avg_seconds = int(average_time.total_seconds() % 60)
    average_str = f"{avg_minutes}:{avg_seconds:02d}"
else:
    average_str = "N/A"

# Print results
print(f"Event Date: {event_date}")
print(f"Total Participants: {total_participants}")
print(f"Average Time: {average_str}")
# Out:
# Event Date: 28/06/2025
# Total Participants: 762
# Average Time: 31:24

# %%
# Updated scraper script again to also get mean age grading. 

# Extract event date
date_element = doc.find('span', class_='format-date')
event_date = date_element.text.strip() if date_element else 'Date not found'

# Extract the total number of participants (position of the last finisher)
table_rows = doc.select('table tbody tr')
total_participants = len(table_rows)

# Extract time values
rows = doc.select('table tbody tr')
times = []
age_grades = []

for row in rows:
    cols = row.find_all('td')
    if len(cols) < 6:
        continue

    # --- TIME ---
    time_raw = cols[5].text.strip()
    time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
    if time_match:
        time_str = time_match.group(1)
        time_parts = time_str.split(':')

        if len(time_parts) == 2:
            minutes, seconds = map(int, time_parts)
            td = timedelta(minutes=minutes, seconds=seconds)
        elif len(time_parts) == 3:
            hours, minutes, seconds = map(int, time_parts)
            td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
        else:
            continue
        times.append(td)

    # --- AGE GRADE ---
    
    age_group_cell = cols[3]
    detailed_div = age_group_cell.find('div', class_='detailed')

    if detailed_div:
        age_grade_text = detailed_div.text.strip()  # e.g. "76.55% age grade"
        match = re.search(r'(\d{1,3}\.\d{2})%', age_grade_text)
        if match:
            age_grade = float(match.group(1))
            age_grades.append(age_grade)
    
# --- AVERAGE TIME ---
if times:
    average_time = sum(times, timedelta()) / len(times)
    avg_minutes = int(average_time.total_seconds() // 60)
    avg_seconds = int(average_time.total_seconds() % 60)
    average_str = f"{avg_minutes}:{avg_seconds:02d}"
else:
    average_str = "N/A"

# --- AVERAGE AGE GRADE ---
if age_grades:
    avg_age_grade = sum(age_grades) / len(age_grades)
    avg_age_grade_str = f"{avg_age_grade:.2f}%"
else:
    avg_age_grade_str = "N/A"

print(f"Event Date: {event_date}")
print(f"Total Participants: {total_participants}")
print(f"Average Time: {average_str}")
print(f"Average Age Grade: {avg_age_grade_str}")
# Out:
# Event Date: 28/06/2025
# Total Participants: 762
# Average Time: 31:24
# Average Age Grade: 51.29%

# %%
# Tidied up my code a bit to make it more succinct and added in event name. 

# Get event name
header_div = doc.find('div', class_='Results-header')
event_name = header_div.find('h1').text.strip() if header_div and header_div.find('h1') else 'Event name not found'

# Extract event date
date_element = doc.find('span', class_='format-date')
event_date = date_element.text.strip() if date_element else 'Date not found'

# Extract all rows and total participants
table_rows = doc.select('table tbody tr')
total_participants = len(table_rows)

times = []
age_grades = []

for row in table_rows:
    cols = row.find_all('td')
    if len(cols) < 6:
        continue

    # --- TIME ---
    time_raw = cols[5].text.strip()
    time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
    if time_match:
        time_str = time_match.group(1)
        time_parts = time_str.split(':')

        if len(time_parts) == 2:
            minutes, seconds = map(int, time_parts)
            td = timedelta(minutes=minutes, seconds=seconds)
        elif len(time_parts) == 3:
            hours, minutes, seconds = map(int, time_parts)
            td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
        else:
            continue
        times.append(td)

    # --- AGE GRADE ---
    age_group_cell = cols[3]
    detailed_div = age_group_cell.find('div', class_='detailed')

    if detailed_div:
        age_grade_text = detailed_div.text.strip()
        match = re.search(r'(\d{1,3}\.\d{2})%', age_grade_text)
        if match:
            age_grade = float(match.group(1))
            age_grades.append(age_grade)

# --- AVERAGE TIME ---
if times:
    average_time = sum(times, timedelta()) / len(times)
    avg_minutes = int(average_time.total_seconds() // 60)
    avg_seconds = int(average_time.total_seconds() % 60)
    average_str = f"{avg_minutes}:{avg_seconds:02d}"
else:
    average_str = "N/A"

# --- AVERAGE AGE GRADE ---
if age_grades:
    avg_age_grade = sum(age_grades) / len(age_grades)
    avg_age_grade_str = f"{avg_age_grade:.2f}%"
else:
    avg_age_grade_str = "N/A"

print(f"Event Name: {event_name}")
print(f"Event Date: {event_date}")
print(f"Total Participants: {total_participants}")
print(f"Average Time: {average_str}")
print(f"Average Age Grade: {avg_age_grade_str}")
# Out:
# Event Name: Albert parkrun, Melbourne
# Event Date: 28/06/2025
# Total Participants: 762
# Average Time: 31:24
# Average Age Grade: 51.29%

# %% [markdown]
# ## I've done the analysis for Albert Melbourne, now to do it for all 49 Melbourne parkruns.

# %%
# First I'm bringing in the csv I greated in Notebook 01.

import csv

input_csv = 'melb_parkruns.csv'

with open(input_csv, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(row['eventname'])
# Out:
# albertmelbourne
# highlands
# hastingsforeshore
# diamondcreek
# berwicksprings
# pointcook
# westerfolds
# lillydalelake
# maribyrnong
# pakenham
# toolerncreek
# froghollow
# parkville
# brimbank
# coburg
# jells
# altonabeach
# wyndhamvale
# studley
# lalor
# chelseabicentennial
# wilsonbotanic
# karkarook
# mullummullum
# darebin
# mernda
# newportlakes
# sunbury
# marriottwaters
# gardinerscreek
# rosebud
# kmreedyreserve
# birdslandreserve
# berwickwaters
# aurora
# warringalparklands
# dandenong
# cyrilcurtainreserve
# cascadesonclydewetlands
# dorsetrecreationreserve
# frankstonnatureconservationres
# lewisparkreserve
# warrandyteriverreserve
# kirkdalereserve
# woodlandshistoricpark
# maroondahdam
# emeraldlake
# aintreereserve
# belvedere

# %%
# Check to make sure it's reading all 49 event names.

count = 0
with open(input_csv, newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        if row['eventname'].strip():
            count += 1

print(f"Total event names: {count}")
# Out:
# Total event names: 49

# %%
def parse_event(eventname):
    url = f"https://www.parkrun.com.au/{eventname}/results/latestresults/"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    res = requests.get(url, headers=headers)
    if res.status_code != 200:
        print(f"Failed to get data for {eventname}, status code: {res.status_code}")
        return None

    doc = BeautifulSoup(res.text, 'html.parser')

    header_div = doc.find('div', class_='Results-header')
    event_name = header_div.find('h1').text.strip() if header_div and header_div.find('h1') else eventname

    date_element = doc.find('span', class_='format-date')
    event_date = date_element.text.strip() if date_element else 'Date not found'

    table_rows = doc.select('table tbody tr')
    total_participants = len(table_rows)

    times = []
    age_grades = []

    for row in table_rows:
        cols = row.find_all('td')
        if len(cols) < 6:
            continue

        time_raw = cols[5].text.strip()
        time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
        if time_match:
            time_str = time_match.group(1)
            time_parts = time_str.split(':')
            if len(time_parts) == 2:
                minutes, seconds = map(int, time_parts)
                td = timedelta(minutes=minutes, seconds=seconds)
            elif len(time_parts) == 3:
                hours, minutes, seconds = map(int, time_parts)
                td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
            else:
                continue
            times.append(td)

        age_group_cell = cols[3]
        detailed_div = age_group_cell.find('div', class_='detailed')
        if detailed_div:
            age_grade_text = detailed_div.text.strip()
            match = re.search(r'(\d{1,3}\.\d{2})%', age_grade_text)
            if match:
                age_grade = float(match.group(1))
                age_grades.append(age_grade)

    if times:
        average_time = sum(times, timedelta()) / len(times)
        avg_minutes = int(average_time.total_seconds() // 60)
        avg_seconds = int(average_time.total_seconds() % 60)
        average_str = f"{avg_minutes}:{avg_seconds:02d}"
    else:
        average_str = "N/A"

    if age_grades:
        avg_age_grade = sum(age_grades) / len(age_grades)
        avg_age_grade_str = f"{avg_age_grade:.2f}%"
    else:
        avg_age_grade_str = "N/A"

    return {
        'event_name': event_name,
        'event_date': event_date,
        'total_participants': total_participants,
        'average_time': average_str,
        'average_age_grade': avg_age_grade_str,
    }

# --- Main ---
input_csv = 'melb_parkruns.csv'
output_csv = 'melb_parkruns_summary.csv'

with open(input_csv, newline='', encoding='utf-8') as f_in, \
     open(output_csv, 'w', newline='', encoding='utf-8') as f_out:

    reader = csv.DictReader(f_in)
    writer = csv.writer(f_out)

    # Write header for output CSV
    writer.writerow(['event_name', 'event_date', 'total_participants', 'average_time', 'average_age_grade'])

    for row in reader:
        eventname = row['eventname'].strip()
        print(f"Processing event: {eventname}")
        data = parse_event(eventname)
        if data:
            writer.writerow([
                data['event_name'],
                data['event_date'],
                data['total_participants'],
                data['average_time'],
                data['average_age_grade'],
            ])
        else:
            print(f"Skipping event {eventname} due to fetch error.")

print("Done! Results saved to", output_csv)
# Out:
# Processing event: albertmelbourne
# Failed to get data for albertmelbourne, status code: 405
# Skipping event albertmelbourne due to fetch error.
# Processing event: highlands
# Failed to get data for highlands, status code: 405
# Skipping event highlands due to fetch error.
# Processing event: hastingsforeshore
# Failed to get data for hastingsforeshore, status code: 405
# Skipping event hastingsforeshore due to fetch error.
# Processing event: diamondcreek
# Failed to get data for diamondcreek, status code: 405
# Skipping event diamondcreek due to fetch error.
# Processing event: berwicksprings
# Failed to get data for berwicksprings, status code: 405
# Skipping event berwicksprings due to fetch error.
# Processing event: pointcook
# Failed to get data for pointcook, status code: 405
# Skipping event pointcook due to fetch error.
# Processing event: westerfolds
# Failed to get data for westerfolds, status code: 405
# Skipping event westerfolds due to fetch error.
# Processing event: lillydalelake
# Failed to get data for lillydalelake, status code: 405
# Skipping event lillydalelake due to fetch error.
# Processing event: maribyrnong
# Failed to get data for maribyrnong, status code: 405
# Skipping event maribyrnong due to fetch error.
# Processing event: pakenham
# Failed to get data for pakenham, status code: 405
# Skipping event pakenham due to fetch error.
# Processing event: toolerncreek
# Failed to get data for toolerncreek, status code: 405
# Skipping event toolerncreek due to fetch error.
# Processing event: froghollow
# Failed to get data for froghollow, status code: 405
# Skipping event froghollow due to fetch error.
# Processing event: parkville
# Failed to get data for parkville, status code: 405
# Skipping event parkville due to fetch error.
# Processing event: brimbank
# Failed to get data for brimbank, status code: 405
# Skipping event brimbank due to fetch error.
# Processing event: coburg
# Failed to get data for coburg, status code: 405
# Skipping event coburg due to fetch error.
# Processing event: jells
# Failed to get data for jells, status code: 405
# Skipping event jells due to fetch error.
# Processing event: altonabeach
# Failed to get data for altonabeach, status code: 405
# Skipping event altonabeach due to fetch error.
# Processing event: wyndhamvale
# Failed to get data for wyndhamvale, status code: 405
# Skipping event wyndhamvale due to fetch error.
# Processing event: studley
# Failed to get data for studley, status code: 405
# Skipping event studley due to fetch error.
# Processing event: lalor
# Failed to get data for lalor, status code: 405
# Skipping event lalor due to fetch error.
# Processing event: chelseabicentennial
# Failed to get data for chelseabicentennial, status code: 405
# Skipping event chelseabicentennial due to fetch error.
# Processing event: wilsonbotanic
# Failed to get data for wilsonbotanic, status code: 405
# Skipping event wilsonbotanic due to fetch error.
# Processing event: karkarook
# Failed to get data for karkarook, status code: 405
# Skipping event karkarook due to fetch error.
# Processing event: mullummullum
# Failed to get data for mullummullum, status code: 405
# Skipping event mullummullum due to fetch error.
# Processing event: darebin
# Failed to get data for darebin, status code: 405
# Skipping event darebin due to fetch error.
# Processing event: mernda
# Failed to get data for mernda, status code: 405
# Skipping event mernda due to fetch error.
# Processing event: newportlakes
# Failed to get data for newportlakes, status code: 405
# Skipping event newportlakes due to fetch error.
# Processing event: sunbury
# Failed to get data for sunbury, status code: 405
# Skipping event sunbury due to fetch error.
# Processing event: marriottwaters
# Failed to get data for marriottwaters, status code: 405
# Skipping event marriottwaters due to fetch error.
# Processing event: gardinerscreek
# Failed to get data for gardinerscreek, status code: 405
# Skipping event gardinerscreek due to fetch error.
# Processing event: rosebud
# Failed to get data for rosebud, status code: 405
# Skipping event rosebud due to fetch error.
# Processing event: kmreedyreserve
# Failed to get data for kmreedyreserve, status code: 405
# Skipping event kmreedyreserve due to fetch error.
# Processing event: birdslandreserve
# Failed to get data for birdslandreserve, status code: 405
# Skipping event birdslandreserve due to fetch error.
# Processing event: berwickwaters
# Failed to get data for berwickwaters, status code: 405
# Skipping event berwickwaters due to fetch error.
# Processing event: aurora
# Failed to get data for aurora, status code: 405
# Skipping event aurora due to fetch error.
# Processing event: warringalparklands
# Failed to get data for warringalparklands, status code: 405
# Skipping event warringalparklands due to fetch error.
# Processing event: dandenong
# Failed to get data for dandenong, status code: 405
# Skipping event dandenong due to fetch error.
# Processing event: cyrilcurtainreserve
# Failed to get data for cyrilcurtainreserve, status code: 405
# Skipping event cyrilcurtainreserve due to fetch error.
# Processing event: cascadesonclydewetlands
# Failed to get data for cascadesonclydewetlands, status code: 405
# Skipping event cascadesonclydewetlands due to fetch error.
# Processing event: dorsetrecreationreserve
# Failed to get data for dorsetrecreationreserve, status code: 405
# Skipping event dorsetrecreationreserve due to fetch error.
# Processing event: frankstonnatureconservationres
# Failed to get data for frankstonnatureconservationres, status code: 405
# Skipping event frankstonnatureconservationres due to fetch error.
# Processing event: lewisparkreserve
# Failed to get data for lewisparkreserve, status code: 405
# Skipping event lewisparkreserve due to fetch error.
# Processing event: warrandyteriverreserve
# Failed to get data for warrandyteriverreserve, status code: 405
# Skipping event warrandyteriverreserve due to fetch error.
# Processing event: kirkdalereserve
# Failed to get data for kirkdalereserve, status code: 405
# Skipping event kirkdalereserve due to fetch error.
# Processing event: woodlandshistoricpark
# Failed to get data for woodlandshistoricpark, status code: 405
# Skipping event woodlandshistoricpark due to fetch error.
# Processing event: maroondahdam
# Failed to get data for maroondahdam, status code: 405
# Skipping event maroondahdam due to fetch error.
# Processing event: emeraldlake
# Failed to get data for emeraldlake, status code: 405
# Skipping event emeraldlake due to fetch error.
# Processing event: aintreereserve
# Failed to get data for aintreereserve, status code: 405
# Skipping event aintreereserve due to fetch error.
# Processing event: belvedere
# Failed to get data for belvedere, status code: 405
# Skipping event belvedere due to fetch error.
# Done! Results saved to melb_parkruns_summary.csv

# %%
import requests
import time
from bs4 import BeautifulSoup
from datetime import timedelta
import re
import csv

def parse_event(eventname):
    url = f"https://www.parkrun.com.au/{eventname}/results/latestresults/"
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
    }

    try:
        res = requests.get(url, headers=headers)
        res.raise_for_status()  # Will raise an HTTPError for bad responses
    except requests.exceptions.RequestException as e:
        print(f"Request failed for {eventname}: {e}")
        return None

    doc = BeautifulSoup(res.text, 'html.parser')

    header_div = doc.find('div', class_='Results-header')
    event_name = header_div.find('h1').text.strip() if header_div and header_div.find('h1') else eventname

    date_element = doc.find('span', class_='format-date')
    event_date = date_element.text.strip() if date_element else 'Date not found'

    table_rows = doc.select('table tbody tr')
    total_participants = len(table_rows)

    times = []
    age_grades = []

    for row in table_rows:
        cols = row.find_all('td')
        if len(cols) < 6:
            continue

        time_raw = cols[5].text.strip()
        time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
        if time_match:
            time_str = time_match.group(1)
            time_parts = time_str.split(':')
            if len(time_parts) == 2:
                minutes, seconds = map(int, time_parts)
                td = timedelta(minutes=minutes, seconds=seconds)
            elif len(time_parts) == 3:
                hours, minutes, seconds = map(int, time_parts)
                td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
            else:
                continue
            times.append(td)

        age_group_cell = cols[3]
        detailed_div = age_group_cell.find('div', class_='detailed')
        if detailed_div:
            age_grade_text = detailed_div.text.strip()
            match = re.search(r'(\d{1,3}\.\d{2})%', age_grade_text)
            if match:
                age_grade = float(match.group(1))
                age_grades.append(age_grade)

    if times:
        average_time = sum(times, timedelta()) / len(times)
        avg_minutes = int(average_time.total_seconds() // 60)
        avg_seconds = int(average_time.total_seconds() % 60)
        average_str = f"{avg_minutes}:{avg_seconds:02d}"
    else:
        average_str = "N/A"

    if age_grades:
        avg_age_grade = sum(age_grades) / len(age_grades)
        avg_age_grade_str = f"{avg_age_grade:.2f}%"
    else:
        avg_age_grade_str = "N/A"

    return {
        'event_name': event_name,
        'event_date': event_date,
        'total_participants': total_participants,
        'average_time': average_str,
        'average_age_grade': avg_age_grade_str,
    }

# Delay between requests
time.sleep(143)

# --- Main ---
input_csv = 'melb_parkruns.csv'
output_csv = 'melb_parkruns_summary.csv'

with open(input_csv, newline='', encoding='utf-8') as f_in, \
     open(output_csv, 'w', newline='', encoding='utf-8') as f_out:

    reader = csv.DictReader(f_in)
    writer = csv.writer(f_out)

    # Write header for output CSV
    writer.writerow(['event_name', 'event_date', 'total_participants', 'average_time', 'average_age_grade'])

    for row in reader:
        eventname = row['eventname'].strip()
        print(f"Processing event: {eventname}")
        data = parse_event(eventname)
        if data:
            writer.writerow([
                data['event_name'],
                data['event_date'],
                data['total_participants'],
                data['average_time'],
                data['average_age_grade'],
            ])
        else:
            print(f"Skipping event {eventname} due to fetch error.")

print("Done! Results saved to", output_csv)
# Out:
# Processing event: albertmelbourne
# Processing event: highlands
# Processing event: hastingsforeshore
# Processing event: diamondcreek
# Processing event: berwicksprings
# Processing event: pointcook
# Processing event: westerfolds
# Processing event: lillydalelake
# Processing event: maribyrnong
# Processing event: pakenham
# Processing event: toolerncreek
# Processing event: froghollow
# Processing event: parkville
# Processing event: brimbank
# Processing event: coburg
# Processing event: jells
# Processing event: altonabeach
# Processing event: wyndhamvale
# Processing event: studley
# Processing event: lalor
# Processing event: chelseabicentennial
# Processing event: wilsonbotanic
# Processing event: karkarook
# Processing event: mullummullum
# Processing event: darebin
# Processing event: mernda
# Processing event: newportlakes
# Processing event: sunbury
# Processing event: marriottwaters
# Processing event: gardinerscreek
# Processing event: rosebud
# Processing event: kmreedyreserve
# Processing event: birdslandreserve
# Processing event: berwickwaters
# Processing event: aurora
# Processing event: warringalparklands
# Processing event: dandenong
# Processing event: cyrilcurtainreserve
# Processing event: cascadesonclydewetlands
# Processing event: dorsetrecreationreserve
# Processing event: frankstonnatureconservationres
# Processing event: lewisparkreserve
# Processing event: warrandyteriverreserve
# Processing event: kirkdalereserve
# Processing event: woodlandshistoricpark
# Processing event: maroondahdam
# Processing event: emeraldlake
# Request failed for emeraldlake: 405 Client Error: Not Allowed for url: https://www.parkrun.com.au/emeraldlake/results/latestresults/
# Skipping event emeraldlake due to fetch error.
# Processing event: aintreereserve
# Request failed for aintreereserve: 405 Client Error: Not Allowed for url: https://www.parkrun.com.au/aintreereserve/results/latestresults/
# Skipping event aintreereserve due to fetch error.
# Processing event: belvedere
# Request failed for belvedere: 405 Client Error: Not Allowed for url: https://www.parkrun.com.au/belvedere/results/latestresults/
# Skipping event belvedere due to fetch error.
# Done! Results saved to melb_parkruns_summary.csv

# %%
# Could only scrape 46/49 events so scraped last three manually.

# %%
# emeraldlake

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' 
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/114.0.0.0 Safari/537.36'
}

response = requests.get('https://www.parkrun.com.au/emeraldlake/results/latestresults/', headers=headers)
response.raise_for_status()

# Parse the HTML content using BeautifulSoup
doc = BeautifulSoup(response.content, 'html.parser')

# Get event name
header_div = doc.find('div', class_='Results-header')
event_name = header_div.find('h1').text.strip() if header_div and header_div.find('h1') else 'Event name not found'

# Extract event date
date_element = doc.find('span', class_='format-date')
event_date = date_element.text.strip() if date_element else 'Date not found'

# Extract all rows and total participants
table_rows = doc.select('table tbody tr')
total_participants = len(table_rows)

times = []
age_grades = []

for row in table_rows:
    cols = row.find_all('td')
    if len(cols) < 6:
        continue

    # --- TIME ---
    time_raw = cols[5].text.strip()
    time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
    if time_match:
        time_str = time_match.group(1)
        time_parts = time_str.split(':')

        if len(time_parts) == 2:
            minutes, seconds = map(int, time_parts)
            td = timedelta(minutes=minutes, seconds=seconds)
        elif len(time_parts) == 3:
            hours, minutes, seconds = map(int, time_parts)
            td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
        else:
            continue
        times.append(td)

    # --- AGE GRADE ---
    age_group_cell = cols[3]
    detailed_div = age_group_cell.find('div', class_='detailed')

    if detailed_div:
        age_grade_text = detailed_div.text.strip()
        match = re.search(r'(\d{1,3}\.\d{2})%', age_grade_text)
        if match:
            age_grade = float(match.group(1))
            age_grades.append(age_grade)

# --- AVERAGE TIME ---
if times:
    average_time = sum(times, timedelta()) / len(times)
    avg_minutes = int(average_time.total_seconds() // 60)
    avg_seconds = int(average_time.total_seconds() % 60)
    average_str = f"{avg_minutes}:{avg_seconds:02d}"
else:
    average_str = "N/A"

# --- AVERAGE AGE GRADE ---
if age_grades:
    avg_age_grade = sum(age_grades) / len(age_grades)
    avg_age_grade_str = f"{avg_age_grade:.2f}%"
else:
    avg_age_grade_str = "N/A"

print(f"Event Name: {event_name}")
print(f"Event Date: {event_date}")
print(f"Total Participants: {total_participants}")
print(f"Average Time: {average_str}")
print(f"Average Age Grade: {avg_age_grade_str}")
# Out:
# Event Name: Emerald Lake parkrun
# Event Date: 28/06/2025
# Total Participants: 44
# Average Time: 32:26
# Average Age Grade: 50.25%

# %%
# aintreereserve

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' 
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/114.0.0.0 Safari/537.36'
}

response = requests.get('https://www.parkrun.com.au/aintreereserve/results/latestresults/', headers=headers)
response.raise_for_status()

# Parse the HTML content using BeautifulSoup
doc = BeautifulSoup(response.content, 'html.parser')

# Get event name
header_div = doc.find('div', class_='Results-header')
event_name = header_div.find('h1').text.strip() if header_div and header_div.find('h1') else 'Event name not found'

# Extract event date
date_element = doc.find('span', class_='format-date')
event_date = date_element.text.strip() if date_element else 'Date not found'

# Extract all rows and total participants
table_rows = doc.select('table tbody tr')
total_participants = len(table_rows)

times = []
age_grades = []

for row in table_rows:
    cols = row.find_all('td')
    if len(cols) < 6:
        continue

    # --- TIME ---
    time_raw = cols[5].text.strip()
    time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
    if time_match:
        time_str = time_match.group(1)
        time_parts = time_str.split(':')

        if len(time_parts) == 2:
            minutes, seconds = map(int, time_parts)
            td = timedelta(minutes=minutes, seconds=seconds)
        elif len(time_parts) == 3:
            hours, minutes, seconds = map(int, time_parts)
            td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
        else:
            continue
        times.append(td)

    # --- AGE GRADE ---
    age_group_cell = cols[3]
    detailed_div = age_group_cell.find('div', class_='detailed')

    if detailed_div:
        age_grade_text = detailed_div.text.strip()
        match = re.search(r'(\d{1,3}\.\d{2})%', age_grade_text)
        if match:
            age_grade = float(match.group(1))
            age_grades.append(age_grade)

# --- AVERAGE TIME ---
if times:
    average_time = sum(times, timedelta()) / len(times)
    avg_minutes = int(average_time.total_seconds() // 60)
    avg_seconds = int(average_time.total_seconds() % 60)
    average_str = f"{avg_minutes}:{avg_seconds:02d}"
else:
    average_str = "N/A"

# --- AVERAGE AGE GRADE ---
if age_grades:
    avg_age_grade = sum(age_grades) / len(age_grades)
    avg_age_grade_str = f"{avg_age_grade:.2f}%"
else:
    avg_age_grade_str = "N/A"

print(f"Event Name: {event_name}")
print(f"Event Date: {event_date}")
print(f"Total Participants: {total_participants}")
print(f"Average Time: {average_str}")
print(f"Average Age Grade: {avg_age_grade_str}")
# Out:
# Event Name: Aintree Reserve parkrun
# Event Date: 28/06/2025
# Total Participants: 61
# Average Time: 32:29
# Average Age Grade: 49.33%

# %%
# belvedere

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) ' 
                  'AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/114.0.0.0 Safari/537.36'
}

response = requests.get('https://www.parkrun.com.au/belvedere/results/latestresults/', headers=headers)
response.raise_for_status()

# Parse the HTML content using BeautifulSoup
doc = BeautifulSoup(response.content, 'html.parser')

# Get event name
header_div = doc.find('div', class_='Results-header')
event_name = header_div.find('h1').text.strip() if header_div and header_div.find('h1') else 'Event name not found'

# Extract event date
date_element = doc.find('span', class_='format-date')
event_date = date_element.text.strip() if date_element else 'Date not found'

# Extract all rows and total participants
table_rows = doc.select('table tbody tr')
total_participants = len(table_rows)

times = []
age_grades = []

for row in table_rows:
    cols = row.find_all('td')
    if len(cols) < 6:
        continue

    # --- TIME ---
    time_raw = cols[5].text.strip()
    time_match = re.search(r'(\d{1,2}:\d{2}(?::\d{2})?)', time_raw)
    if time_match:
        time_str = time_match.group(1)
        time_parts = time_str.split(':')

        if len(time_parts) == 2:
            minutes, seconds = map(int, time_parts)
            td = timedelta(minutes=minutes, seconds=seconds)
        elif len(time_parts) == 3:
            hours, minutes, seconds = map(int, time_parts)
            td = timedelta(hours=hours, minutes=minutes, seconds=seconds)
        else:
            continue
        times.append(td)

    # --- AGE GRADE ---
    age_group_cell = cols[3]
    detailed_div = age_group_cell.find('div', class_='detailed')

    if detailed_div:
        age_grade_text = detailed_div.text.strip()
        match = re.search(r'(\d{1,3}\.\d{2})%', age_grade_text)
        if match:
            age_grade = float(match.group(1))
            age_grades.append(age_grade)

# --- AVERAGE TIME ---
if times:
    average_time = sum(times, timedelta()) / len(times)
    avg_minutes = int(average_time.total_seconds() // 60)
    avg_seconds = int(average_time.total_seconds() % 60)
    average_str = f"{avg_minutes}:{avg_seconds:02d}"
else:
    average_str = "N/A"

# --- AVERAGE AGE GRADE ---
if age_grades:
    avg_age_grade = sum(age_grades) / len(age_grades)
    avg_age_grade_str = f"{avg_age_grade:.2f}%"
else:
    avg_age_grade_str = "N/A"

print(f"Event Name: {event_name}")
print(f"Event Date: {event_date}")
print(f"Total Participants: {total_participants}")
print(f"Average Time: {average_str}")
print(f"Average Age Grade: {avg_age_grade_str}")
# Out:
# Event Name: Belvedere parkrun
# Event Date: 28/06/2025
# Total Participants: 220
# Average Time: 33:27
# Average Age Grade: 51.18%

# %%
import pandas as pd

df = pd.read_csv('melb_parkruns_summary.csv')
df
# Out:
#                                        event_name  event_date  \
# 0                       Albert parkrun, Melbourne  28/06/2025
# 1                               Highlands parkrun  28/06/2025
# 2                      Hastings Foreshore parkrun  28/06/2025
# 3                           Diamond Creek parkrun  28/06/2025
# 4                         Berwick Springs parkrun  28/06/2025
# 5                              Point Cook parkrun  28/06/2025
# 6                             Westerfolds parkrun  28/06/2025
# 7                          Lillydale Lake parkrun  28/06/2025
# 8                             Maribyrnong parkrun  28/06/2025
# 9                                Pakenham parkrun  28/06/2025
# 10                          Toolern Creek parkrun  28/06/2025
# 11                            Frog Hollow parkrun  28/06/2025
# 12                              Parkville parkrun  28/06/2025
# 13                               Brimbank parkrun  28/06/2025
# 14                                 Coburg parkrun  28/06/2025
# 15                                  Jells parkrun  28/06/2025
# 16                           Altona Beach parkrun  28/06/2025
# 17                           Wyndham Vale parkrun  28/06/2025
# 18                                Studley parkrun  28/06/2025
# 19                                  Lalor parkrun  28/06/2025
# 20                   Chelsea Bicentennial parkrun  28/06/2025
# 21                         Wilson Botanic parkrun  28/06/2025
# 22                              Karkarook parkrun  28/06/2025
# 23                          Mullum Mullum parkrun  28/06/2025
# 24                                Darebin parkrun  28/06/2025
# 25                                 Mernda parkrun  28/06/2025
# 26                          Newport Lakes parkrun  28/06/2025
# 27                                Sunbury parkrun  28/06/2025
# 28                        Marriott Waters parkrun  28/06/2025
# 29                        Gardiners Creek parkrun  28/06/2025
# 30                                Rosebud parkrun  28/06/2025
# 31                       KM Reedy Reserve parkrun  28/06/2025
# 32                      Birdsland Reserve parkrun  28/06/2025
# 33                         Berwick Waters parkrun  28/06/2025
# 34                                 Aurora parkrun  28/06/2025
# 35                    Warringal Parklands parkrun  28/06/2025
# 36                              Dandenong parkrun  28/06/2025
# 37                  Cyril Curtain Reserve parkrun  28/06/2025
# 38             Cascades on Clyde Wetlands parkrun  28/06/2025
# 39              Dorset Recreation Reserve parkrun  28/06/2025
# 40  Frankston Nature Conservation Reserve parkrun  28/06/2025
# 41                     Lewis Park Reserve parkrun  28/06/2025
# 42               Warrandyte River Reserve parkrun  28/06/2025
# 43                       Kirkdale Reserve parkrun  28/06/2025
# 44                Woodlands Historic Park parkrun  28/06/2025
# 45                          Maroondah Dam parkrun  28/06/2025
#
#     total_participants average_time average_age_grade
# 0                  762        31:24            51.29%
# 1                   85        36:30            46.54%
# 2                  171        32:47            52.30%
# 3                  294        33:14            51.12%
# 4                  184        32:42            51.29%
# 5                  138        33:28            48.13%
# 6                  166        33:02            49.61%
# 7                  220        29:55            54.20%
# 8                  414        30:49            52.66%
# 9                  159        32:32            50.97%
# 10                  77        40:14            44.26%
# 11                  90        35:16            49.22%
# 12                 508        29:59            51.75%
# 13                  89        37:52            44.28%
# 14                 214        32:47            49.99%
# 15                 369        33:14            49.70%
# 16                 146        32:03            50.45%
# 17                 132        35:50            46.93%
# 18                 307        32:21            50.21%
# 19                  55        33:19            47.81%
# 20                 318        32:19            51.27%
# 21                  74        35:39            49.04%
# 22                 398        31:23            52.00%
# 23                 208        34:42            47.53%
# 24                 151        35:25            47.58%
# 25                  70        37:42            45.33%
# 26                 135        35:15            47.79%
# 27                  95        41:43            42.13%
# 28                 106        34:21            49.45%
# 29                 420        31:58            50.87%
# 30                 164        32:54            53.42%
# 31                  31        32:01            51.96%
# 32                 101        33:03            50.42%
# 33                  90        33:36            47.44%
# 34                  55        39:32            43.12%
# 35                 296        30:56            52.64%
# 36                  77        33:00            50.72%
# 37                  68        31:08            52.86%
# 38                  33        35:25            46.45%
# 39                 219        32:58            51.17%
# 40                  85        34:26            49.25%
# 41                 235        34:59            48.26%
# 42                  70        30:50            51.91%
# 43                 184        31:25            51.04%
# 44                  90        35:59            47.13%
# 45                  32        37:41            45.73%

# %%
df.columns
# Out:
# Index(['event_name', 'event_date', 'total_participants', 'average_time',
#        'average_age_grade'],
#       dtype='object')

# %%
new_events = [
    {
        "event_name": "Emerald Lake parkrun",
        "event_date": "28/06/2025",
        "total_participants": 44,
        "average_time": "32:26",
        "average_age_grade": "50.25%"
    },
    {
        "event_name": "Aintree Reserve parkrun",
        "event_date": "28/06/2025",
        "total_participants": 61,
        "average_time": "32:29",
        "average_age_grade": "49.33%"
    },
    {
        "event_name": "Belvedere parkrun",
        "event_date": "28/06/2025",
        "total_participants": 220,
        "average_time": "33:27",
        "average_age_grade": "51.18%"
    }
]

df_new = pd.DataFrame(new_events)

# %%
df_combined = pd.concat([df, df_new], ignore_index=True)
df_combined
# Out:
#                                        event_name  event_date  \
# 0                       Albert parkrun, Melbourne  28/06/2025
# 1                               Highlands parkrun  28/06/2025
# 2                      Hastings Foreshore parkrun  28/06/2025
# 3                           Diamond Creek parkrun  28/06/2025
# 4                         Berwick Springs parkrun  28/06/2025
# 5                              Point Cook parkrun  28/06/2025
# 6                             Westerfolds parkrun  28/06/2025
# 7                          Lillydale Lake parkrun  28/06/2025
# 8                             Maribyrnong parkrun  28/06/2025
# 9                                Pakenham parkrun  28/06/2025
# 10                          Toolern Creek parkrun  28/06/2025
# 11                            Frog Hollow parkrun  28/06/2025
# 12                              Parkville parkrun  28/06/2025
# 13                               Brimbank parkrun  28/06/2025
# 14                                 Coburg parkrun  28/06/2025
# 15                                  Jells parkrun  28/06/2025
# 16                           Altona Beach parkrun  28/06/2025
# 17                           Wyndham Vale parkrun  28/06/2025
# 18                                Studley parkrun  28/06/2025
# 19                                  Lalor parkrun  28/06/2025
# 20                   Chelsea Bicentennial parkrun  28/06/2025
# 21                         Wilson Botanic parkrun  28/06/2025
# 22                              Karkarook parkrun  28/06/2025
# 23                          Mullum Mullum parkrun  28/06/2025
# 24                                Darebin parkrun  28/06/2025
# 25                                 Mernda parkrun  28/06/2025
# 26                          Newport Lakes parkrun  28/06/2025
# 27                                Sunbury parkrun  28/06/2025
# 28                        Marriott Waters parkrun  28/06/2025
# 29                        Gardiners Creek parkrun  28/06/2025
# 30                                Rosebud parkrun  28/06/2025
# 31                       KM Reedy Reserve parkrun  28/06/2025
# 32                      Birdsland Reserve parkrun  28/06/2025
# 33                         Berwick Waters parkrun  28/06/2025
# 34                                 Aurora parkrun  28/06/2025
# 35                    Warringal Parklands parkrun  28/06/2025
# 36                              Dandenong parkrun  28/06/2025
# 37                  Cyril Curtain Reserve parkrun  28/06/2025
# 38             Cascades on Clyde Wetlands parkrun  28/06/2025
# 39              Dorset Recreation Reserve parkrun  28/06/2025
# 40  Frankston Nature Conservation Reserve parkrun  28/06/2025
# 41                     Lewis Park Reserve parkrun  28/06/2025
# 42               Warrandyte River Reserve parkrun  28/06/2025
# 43                       Kirkdale Reserve parkrun  28/06/2025
# 44                Woodlands Historic Park parkrun  28/06/2025
# 45                          Maroondah Dam parkrun  28/06/2025
# 46                           Emerald Lake parkrun  28/06/2025
# 47                        Aintree Reserve parkrun  28/06/2025
# 48                              Belvedere parkrun  28/06/2025
#
#     total_participants average_time average_age_grade
# 0                  762        31:24            51.29%
# 1                   85        36:30            46.54%
# 2                  171        32:47            52.30%
# 3                  294        33:14            51.12%
# 4                  184        32:42            51.29%
# 5                  138        33:28            48.13%
# 6                  166        33:02            49.61%
# 7                  220        29:55            54.20%
# 8                  414        30:49            52.66%
# 9                  159        32:32            50.97%
# 10                  77        40:14            44.26%
# 11                  90        35:16            49.22%
# 12                 508        29:59            51.75%
# 13                  89        37:52            44.28%
# 14                 214        32:47            49.99%
# 15                 369        33:14            49.70%
# 16                 146        32:03            50.45%
# 17                 132        35:50            46.93%
# 18                 307        32:21            50.21%
# 19                  55        33:19            47.81%
# 20                 318        32:19            51.27%
# 21                  74        35:39            49.04%
# 22                 398        31:23            52.00%
# 23                 208        34:42            47.53%
# 24                 151        35:25            47.58%
# 25                  70        37:42            45.33%
# 26                 135        35:15            47.79%
# 27                  95        41:43            42.13%
# 28                 106        34:21            49.45%
# 29                 420        31:58            50.87%
# 30                 164        32:54            53.42%
# 31                  31        32:01            51.96%
# 32                 101        33:03            50.42%
# 33                  90        33:36            47.44%
# 34                  55        39:32            43.12%
# 35                 296        30:56            52.64%
# 36                  77        33:00            50.72%
# 37                  68        31:08            52.86%
# 38                  33        35:25            46.45%
# 39                 219        32:58            51.17%
# 40                  85        34:26            49.25%
# 41                 235        34:59            48.26%
# 42                  70        30:50            51.91%
# 43                 184        31:25            51.04%
# 44                  90        35:59            47.13%
# 45                  32        37:41            45.73%
# 46                  44        32:26            50.25%
# 47                  61        32:29            49.33%
# 48                 220        33:27            51.18%

# %%
df_combined.to_csv('melb_parkruns_summary.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_combined.to_csv('melb_parkruns_summary.csv', index=False)
#
# NameError: name 'df_combined' is not defined

# %% [markdown]
# For some reason my csv file has become corrupted and has turned all the MM:SS average_time values to HH:MM:00. I have saved a version of the data as an Excel Workbook to get around this problem as re-pasting the correct values into the columns does not persist after saving it.
#
# **UPDATE:** There was nothing wrong with my csv file, it was how Excel was automatically formatting it that was the problem. Still got to have create an Excel Workbook version for manipulating the data in Excel.

# %% [markdown]
# **NOTE:** Didn't realise that parkrun had a no scraping policy (https://www.parkrun.com/scraping) but as I'm using this data for a university assignment it is personal, non-commercial use.
